# %%
import pandas as pd

# %% [raw]
# pip install pandas in pwlab

# %%
df = pd.read_csv('India_Injury_Road_Accident_Fatality_2017-2020.csv')

# %%
#TO print first 5 records of a data set
#---->> In this case it will print first row as a column  
df.head()
# Out:
#                State  Road Accidents  during 2018  \
# 0     Andhra Pradesh                        24475
# 1  Arunachal Pradesh                          277
# 2              Assam                         8248
# 3              Bihar                         9600
# 4       Chhattisgarh                        13864
#
#     Road Accidents  during 2019  Road Accidents  during 2020  \
# 0                         21992                      19509.0
# 1                           237                        134.0
# 2                          8350                       6595.0
# 3                         10007                       8639.0
# 4                         13899                      11656.0
#
#    Accidents  Per Lakh Population - 2017  \
# 0                                   28.7
# 1                                   18.0
# 2                                   21.6
# 3                                    8.3
# 4                                   51.2
#
# ...

# %%
#df = pd.read_csv('India_Injury_Road_Accident_Fatality_2017-2020.csv', header = None) #This will not read first row as a column this will include column wala index as a oth row

# %%
df.head(3)
# Out:
#                State  Road Accidents  during 2018  \
# 0     Andhra Pradesh                        24475
# 1  Arunachal Pradesh                          277
# 2              Assam                         8248
#
#     Road Accidents  during 2019  Road Accidents  during 2020  \
# 0                         21992                      19509.0
# 1                           237                        134.0
# 2                          8350                       6595.0
#
#    Accidents  Per Lakh Population - 2017  \
# 0                                   28.7
# 1                                   18.0
# 2                                   21.6
#
#    Total Number of Accidents  Per Lakh Population - 2018  \
# 0                                               27.1
# 1                                               20.5
# 2                                               24.6
#
#    Total Number of Accidents  Per Lakh Population - 2019  \
# 0                                               24.2
# ...

# %%
df.tail() #This will return last 5 row
# Out:
#             State  Road Accidents  during 2018   Road Accidents  during 2019  \
# 32  Daman and Diu                           76                            69
# 33          Delhi                         6515                          5610
# 34    Lakshadweep                            3                             1
# 35     Puducherry                         1597                          1392
# 36         Total                        467044                        449002
#
#     Road Accidents  during 2020  Accidents  Per Lakh Population - 2017  \
# 32                          NaN                                   22.0
# 33                       4178.0                                   29.6
# 34                          1.0                                    1.2
# 35                        969.0                                   94.2
# 36                     366138.0                                   35.8
#
#     Total Number of Accidents  Per Lakh Population - 2018  \
# ...

# %%
df.tail(2) #this will return last two rows
# Out:
#          State  Road Accidents  during 2018   Road Accidents  during 2019  \
# 35  Puducherry                         1597                          1392
# 36      Total                        467044                        449002
#
#     Road Accidents  during 2020  Accidents  Per Lakh Population - 2017  \
# 35                        969.0                                   94.2
# 36                     366138.0                                   35.8
#
#     Total Number of Accidents  Per Lakh Population - 2018  \
# 35                                               85.5
# 36                                               35.6
#
#     Total Number of Accidents  Per Lakh Population - 2019  \
# 35                                               71.6
# 36                                               33.8
#
#     Total Number of Accidents  Per Lakh Population - 2020  \
# 35                                               49.8
# 36                                               27.6
#
# ...

# %%
df.tail(1) #This will return last row
# Out:
#      State  Road Accidents  during 2018   Road Accidents  during 2019  \
# 36  Total                        467044                        449002
#
#     Road Accidents  during 2020  Accidents  Per Lakh Population - 2017  \
# 36                     366138.0                                   35.8
#
#     Total Number of Accidents  Per Lakh Population - 2018  \
# 36                                               35.6
#
#     Total Number of Accidents  Per Lakh Population - 2019  \
# 36                                               33.8
#
#     Total Number of Accidents  Per Lakh Population - 2020  \
# 36                                               27.6
#
#     Accidents per 10,000 Vehicles - 2017  \
# 36                                  18.4
#
#     Accidents per 10,000 Vehicles - 2018  ...  \
# 36                                  17.1  ...
#
#     Injury Per Lakh Population - 2018  Injury Per Lakh Population - 2019  \
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns #This will print column names
# Out:
# Index(['State', 'Road Accidents  during 2018', ' Road Accidents  during 2019',
#        'Road Accidents  during 2020', 'Accidents  Per Lakh Population - 2017',
#        'Total Number of Accidents  Per Lakh Population - 2018',
#        'Total Number of Accidents  Per Lakh Population - 2019',
#        'Total Number of Accidents  Per Lakh Population - 2020',
#        'Accidents per 10,000 Vehicles - 2017',
#        'Accidents per 10,000 Vehicles - 2018',
#        'Accidents per 10,000 Vehicles - 2019',
#        'Accidents per 10,000 Km of Roads - 2017',
#        'Accidents per 10,000 Km of Roads - 2018', 'Persons Killed 2017',
#        'Persons Killed 2018', 'Persons Killed 2019', 'Persons Killed 2020',
#        'Share in Death- 2017', 'Share in Death- 2018', 'Share in Death- 2019',
#        'Share in Death- 2020', 'Persons Killed Per Lakh Population - 2017',
#        'Persons Killed Per Lakh Population - 2018',
#        'Persons Killed Per Lakh Population - 2019',
# ...

# %%
#If we want to convert it into list then
list(df.columns)
# Out:
# ['State',
#  'Road Accidents  during 2018',
#  ' Road Accidents  during 2019',
#  'Road Accidents  during 2020',
#  'Accidents  Per Lakh Population - 2017',
#  'Total Number of Accidents  Per Lakh Population - 2018',
#  'Total Number of Accidents  Per Lakh Population - 2019',
#  'Total Number of Accidents  Per Lakh Population - 2020',
#  'Accidents per 10,000 Vehicles - 2017',
#  'Accidents per 10,000 Vehicles - 2018',
#  'Accidents per 10,000 Vehicles - 2019',
#  'Accidents per 10,000 Km of Roads - 2017',
#  'Accidents per 10,000 Km of Roads - 2018',
#  'Persons Killed 2017',
#  'Persons Killed 2018',
#  'Persons Killed 2019',
#  'Persons Killed 2020',
#  'Share in Death- 2017',
#  'Share in Death- 2018',
#  'Share in Death- 2019',
#  'Share in Death- 2020',
#  'Persons Killed Per Lakh Population - 2017',
#  'Persons Killed Per Lakh Population - 2018',
#  'Persons Killed Per Lakh Population - 2019',
#  'Persons Killed Per Lakh Population - 2020',
# ...

# %%
#To print a single column
df['State']
# Out:
# 0                  Andhra Pradesh
# 1               Arunachal Pradesh
# 2                           Assam
# 3                           Bihar
# 4                    Chhattisgarh
# 5                             Goa
# 6                         Gujarat
# 7                         Haryana
# 8                Himachal Pradesh
# 9               Jammu and Kashmir
# 10                      Jharkhand
# 11                      Karnataka
# 12                         Kerala
# 13                 Madhya Pradesh
# 14                    Maharashtra
# 15                        Manipur
# 16                      Meghalaya
# 17                        Mizoram
# 18                       Nagaland
# 19                         Odisha
# 20                         Punjab
# 21                      Rajasthan
# 22                         Sikkim
# 23                     Tamil Nadu
# 24                      Telangana
# 25                        Tripura
# 26                    Uttarakhand
# ...

# %%
type(df['State']) #This will return series series is nothing but equivalent to list
# Out:
# pandas.core.series.Series

# %%
#to convert it into list
list(df['State'])
# Out:
# ['Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Chhattisgarh',
#  'Goa',
#  'Gujarat',
#  'Haryana',
#  'Himachal Pradesh',
#  'Jammu and Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Maharashtra',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Odisha',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Telangana',
#  'Tripura',
#  'Uttarakhand',
#  'Uttar Pradesh',
#  'West Bengal',
#  'Andaman and Nicobar Islands',
#  'Chandigarh',
#  'Dadra and Nagar Haveli',
#  'Daman and Diu',
#  'Delhi',
#  'Lakshadweep',
#  'Puducherry',
#  'Total ']

# %%
k = '10 min'
type(k)
# Out:
# str

# %% [raw]
# difference between list and series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[['State']] #In this line column state is passing as a list
# Out:
#                           State
# 0                Andhra Pradesh
# 1             Arunachal Pradesh
# 2                         Assam
# 3                         Bihar
# 4                  Chhattisgarh
# 5                           Goa
# 6                       Gujarat
# 7                       Haryana
# 8              Himachal Pradesh
# 9             Jammu and Kashmir
# 10                    Jharkhand
# 11                    Karnataka
# 12                       Kerala
# 13               Madhya Pradesh
# 14                  Maharashtra
# 15                      Manipur
# 16                    Meghalaya
# 17                      Mizoram
# 18                     Nagaland
# 19                       Odisha
# 20                       Punjab
# 21                    Rajasthan
# 22                       Sikkim
# 23                   Tamil Nadu
# 24                    Telangana
# 25                      Tripura
# 26                  Uttarakhand
# 27                Uttar Pradesh
# ...

# %%
df[['State','Road Accidents  during 2018']] #In this line of code will select multiple column and data type of this line Dframe
# Out:
#                           State  Road Accidents  during 2018
# 0                Andhra Pradesh                        24475
# 1             Arunachal Pradesh                          277
# 2                         Assam                         8248
# 3                         Bihar                         9600
# 4                  Chhattisgarh                        13864
# 5                           Goa                         3709
# 6                       Gujarat                        18769
# 7                       Haryana                        11238
# 8              Himachal Pradesh                         3110
# 9             Jammu and Kashmir                         5978
# 10                    Jharkhand                         5394
# 11                    Karnataka                        41707
# 12                       Kerala                        40181
# 13               Madhya Pradesh                        51397
# ...

# %%
df.dtypes # THis line will print data type of each column (Here object datatype means string it shows it is string type)
# Out:
# State                                                     object
# Road Accidents  during 2018                                int64
#  Road Accidents  during 2019                               int64
# Road Accidents  during 2020                              float64
# Accidents  Per Lakh Population - 2017                    float64
# Total Number of Accidents  Per Lakh Population - 2018    float64
# Total Number of Accidents  Per Lakh Population - 2019    float64
# Total Number of Accidents  Per Lakh Population - 2020    float64
# Accidents per 10,000 Vehicles - 2017                     float64
# Accidents per 10,000 Vehicles - 2018                     float64
# Accidents per 10,000 Vehicles - 2019                     float64
# Accidents per 10,000 Km of Roads - 2017                  float64
# Accidents per 10,000 Km of Roads - 2018                  float64
# Persons Killed 2017                                        int64
# ...

# %% [raw]
# Way to read excel file

# %%
df1 = pd.read_excel('Historicalinvesttemp.xlsx')

# %%
#For reading multiple sheet from a excel file because in case of excel it reads first sheet by default
#pd.read_excel('',sheetname)

# %%
df1
# Out:
#    Unnamed: 0                        Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0         NaN                               NaN        NaN        NaN
# 1         NaN                               NaN        NaN        NaN
# 2         NaN                               NaN        NaN        NaN
# 3         NaN                               NaN        NaN        NaN
# 4         NaN  Annual Returns on Investments in        NaN        NaN
# ..        ...                               ...        ...        ...
# 85       2007                            0.0549     0.0988     0.0466
# 86       2008                             -0.37     0.2587      0.016
# 87       2009                            0.2646     -0.149      0.001
# 88        NaN                            stocks     tbills      bonds
# 89   averages                               NaN        NaN        NaN
#
# [90 rows x 4 columns]

# %%
df1 = pd.read_excel('Historicalinvesttemp.xlsx')

# %%
df1
# Out:
#    Unnamed: 0                        Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0         NaN                               NaN        NaN        NaN
# 1         NaN                               NaN        NaN        NaN
# 2         NaN                               NaN        NaN        NaN
# 3         NaN                               NaN        NaN        NaN
# 4         NaN  Annual Returns on Investments in        NaN        NaN
# ..        ...                               ...        ...        ...
# 85       2007                            0.0549     0.0988     0.0466
# 86       2008                             -0.37     0.2587      0.016
# 87       2009                            0.2646     -0.149      0.001
# 88        NaN                            stocks     tbills      bonds
# 89   averages                               NaN        NaN        NaN
#
# [90 rows x 4 columns]

# %%
df1.dtypes
# Out:
# Unnamed: 0    object
# Unnamed: 1    object
# Unnamed: 2    object
# Unnamed: 3    object
# dtype: object

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3'], dtype='object')

# %%
df1['Unnamed: 0']
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#         ...
# 85        2007
# 86        2008
# 87        2009
# 88         NaN
# 89    averages
# Name: Unnamed: 0, Length: 90, dtype: object

# %%
df1[['Unnamed: 0','Unnamed: 1','Unnamed: 2']]
# Out:
#    Unnamed: 0                        Unnamed: 1 Unnamed: 2
# 0         NaN                               NaN        NaN
# 1         NaN                               NaN        NaN
# 2         NaN                               NaN        NaN
# 3         NaN                               NaN        NaN
# 4         NaN  Annual Returns on Investments in        NaN
# ..        ...                               ...        ...
# 85       2007                            0.0549     0.0988
# 86       2008                             -0.37     0.2587
# 87       2009                            0.2646     -0.149
# 88        NaN                            stocks     tbills
# 89   averages                               NaN        NaN
#
# [90 rows x 3 columns]

# %%
#To read a csv link
#pd.read_csv('link')

# %%
url_data = pd.read_html('https://www.basketball-reference.com/')
url_data
# Out:
# [          East Unnamed: 1 Unnamed: 2   W   L
#  0    MIL * (1)          F          $  58  24
#  1    BOS * (2)          F          $  57  25
#  2    PHI * (3)          F          $  54  28
#  3    CLE * (4)          F          $  51  31
#  4    NYK * (5)          F          $  47  35
#  5    BRK * (6)          F          $  45  37
#  6    MIA * (7)          F          $  44  38
#  7    ATL * (8)          F          $  41  41
#  8    TOR * (9)          F          $  41  41
#  9   CHI * (10)          F          $  40  42
#  10  IND x (11)          F          $  35  47
#  11  WAS x (12)          F          $  35  47
#  12  ORL x (13)          F          $  34  48
#  13  CHO x (14)          F          $  27  55
#  14  DET x (15)          F          $  17  65,
#            West Unnamed: 1 Unnamed: 2   W   L
#  0    DEN * (1)          F          $  53  29
#  1    MEM * (2)          F          $  51  31
#  2    SAC * (3)          F          $  48  34
# ...

# %%
type(url_data)
# Out:
# list

# %%
len(url_data)
# Out:
# 25

# %%
url_data[0]
# Out:
#           East Unnamed: 1 Unnamed: 2   W   L
# 0    MIL * (1)          F          $  58  24
# 1    BOS * (2)          F          $  57  25
# 2    PHI * (3)          F          $  54  28
# 3    CLE * (4)          F          $  51  31
# 4    NYK * (5)          F          $  47  35
# 5    BRK * (6)          F          $  45  37
# 6    MIA * (7)          F          $  44  38
# 7    ATL * (8)          F          $  41  41
# 8    TOR * (9)          F          $  41  41
# 9   CHI * (10)          F          $  40  42
# 10  IND x (11)          F          $  35  47
# 11  WAS x (12)          F          $  35  47
# 12  ORL x (13)          F          $  34  48
# 13  CHO x (14)          F          $  27  55
# 14  DET x (15)          F          $  17  65

# %%
url_data[1]
# Out:
#           West Unnamed: 1 Unnamed: 2   W   L
# 0    DEN * (1)          F          $  53  29
# 1    MEM * (2)          F          $  51  31
# 2    SAC * (3)          F          $  48  34
# 3    PHO * (4)          F          $  45  37
# 4    LAC * (5)          F          $  44  38
# 5    GSW * (6)          F          $  44  38
# 6    LAL * (7)          F          $  43  39
# 7    MIN * (8)          F          $  42  40
# 8    NOP * (9)          F          $  42  40
# 9   OKC * (10)          F          $  40  42
# 10  DAL x (11)          F          $  38  44
# 11  UTA x (12)          F          $  37  45
# 12  POR x (13)          F          $  33  49
# 13  HOU x (14)          F          $  22  60
# 14  SAS x (15)          F          $  22  60

# %%
df3 = url_data[16]
df3
# Out:
#       Unnamed: 0_level_0 Regular Season
#                     Team              W   L   W/L%    GB
# 0     Maccabi Tel Aviv *             19   3  0.864     -
# 1          Bnei Herzliya             10  12  0.455   9.0
# 2     Hapoel Jerusalem *             15   7  0.682   4.0
# 3      Hapoel Tel Aviv *             18   4  0.818   1.0
# 4     Hapoel Be'er Sheva             10  12  0.455   9.0
# 5           Hapoel Haifa              6  16  0.273  13.0
# 6         Hapoel Holon *             14   8  0.636   5.0
# 7       Ironi Kiryat Ata              7  15  0.318  12.0
# 8   Hapoel Galil Elyon *             11  11  0.500   8.0
# 9           Hapoel Eilat              7  15  0.318  12.0
# 10    Ironi Ness Ziona *             11  11  0.500   8.0
# 11   Hapoel Gilboa Galil              4  18  0.182  15.0

# %%
df3.head(3)
# Out:
#           Unnamed: 0_level_0 Regular Season
#                         Team              W   L   W/L%   GB
# 0   Virtus Segafredo Bologna             23   7  0.767    -
# 1  AX Armani Exchange Milano             23   7  0.767    -
# 2   Bertram Derthona Tortona             18  12  0.600  5.0

# %%
df3.dtypes
# Out:
# Unnamed: 0_level_0  Team     object
# Regular Season      W         int64
#                     L         int64
#                     W/L%    float64
#                     GB       object
# dtype: object

# %%
df3[['Unnamed: 0_level_0']]
# Out:
#       Unnamed: 0_level_0
#                     Team
# 0     Maccabi Tel Aviv *
# 1          Bnei Herzliya
# 2     Hapoel Jerusalem *
# 3      Hapoel Tel Aviv *
# 4     Hapoel Be'er Sheva
# 5           Hapoel Haifa
# 6         Hapoel Holon *
# 7       Ironi Kiryat Ata
# 8   Hapoel Galil Elyon *
# 9           Hapoel Eilat
# 10    Ironi Ness Ziona *
# 11   Hapoel Gilboa Galil

# %%
df3[['Regular Season']]
# Out:
#    Regular Season
#                 W   L   W/L%    GB
# 0              19   3  0.864     -
# 1              10  12  0.455   9.0
# 2              15   7  0.682   4.0
# 3              18   4  0.818   1.0
# 4              10  12  0.455   9.0
# 5               6  16  0.273  13.0
# 6              14   8  0.636   5.0
# 7               7  15  0.318  12.0
# 8              11  11  0.500   8.0
# 9               7  15  0.318  12.0
# 10             11  11  0.500   8.0
# 11              4  18  0.182  15.0

# %% [markdown]
# how to store the data which are available online and we are accessing through link to other place or to a csv file  where we dont need to execulte again and again to access it

# %%
df3.to_csv("team_data.csv") #Here team_data.csv is the name of oure file where we are storing the online html data

# %% [raw]
# Here the problem is in this case the csv file also store the indexes of row in it but we dont want to store that so let's see what we can do to do so

# %%
df3.to_csv("team_data.csv", index = False)#This will not include or store  index

# %% [raw]
# suppose we dont want to store column then we need to pass another parameter for column

# %%
df3.to_csv("team_data.csv", columns = None)#This will not include or store column
